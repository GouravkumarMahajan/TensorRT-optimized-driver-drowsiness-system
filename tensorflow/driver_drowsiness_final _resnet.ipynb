# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import cv2
from tensorflow.keras.layers import Flatten, Dense, Activation
import matplotlib.pyplot as plt
from scipy.integrate import simps
from tensorflow.keras import layers
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import numpy as np
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
import visualkeras
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall, AUC
from PIL import Image
import pickle
# Out:
# 2024-08-22 13:54:43.087475: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 13:54:43.087523: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 13:54:43.087559: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-22 13:54:43.095869: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## extracting_images , Data preprocessing and augmentation

# %%
dataset_dir=r"/home/gourav/Desktop/vss/capstone/dataset/train"
classes=['eyes-close','eyes-open']
input_shape = (224, 224, 3)
num_classes = 1
batch_size = 32
epochs = 650


train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(input_shape[0], input_shape[1]),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='rgb', 
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(input_shape[0], input_shape[1]),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='rgb',
    subset='validation'
)
# Out:
# Found 25015 images belonging to 2 classes.
# Found 6253 images belonging to 2 classes.

# %% [markdown]
# ## visualization of images

# %%
batch = next(train_generator)

images = batch[0] 
labels = batch[1] 

# Plot the images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i], cmap='gray') 
    plt.title(f"Label: {labels[i]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# ## model

# %%
base_model = ResNet50(input_shape=input_shape, include_top=False, weights='imagenet')
print(base_model.name)
for layer in base_model.layers[:-100]:
    layer.trainable = False

base_input = base_model.input
base_output = base_model.layers[-1].output  

x = GlobalAveragePooling2D()(base_output)  
x = x = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x) 
final_output = Dense(num_classes)(x) 

final_model = Model(inputs=base_input, outputs=final_output)
# Out:
# resnet50

# %% [markdown]
# ## adding checkpoints

# %%
# checkpoint = ModelCheckpoint(
#     '/home/gourav/Desktop/vss/capstone/best_model_vgg_check.h5', 
#     monitor='val_binary_accuracy',                    
#     verbose=1,                                         
#     save_best_only=True,                               
#     mode='max'                                         
# )

# %% [markdown]
# ## compiling

# %%
final_model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Precision(), keras.metrics.Recall(), keras.metrics.AUC()])

final_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_4[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 512)                  1049088   ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dropout_3 (Dropout)         (None, 512)                  0         ['dense_6[0][0]']
#
#  batch_normalization_3 (Bat  (None, 512)                  2048      ['dropout_3[0][0]']
#  chNormalization)
#
#  dense_7 (Dense)             (None, 1)                    513       ['batch_normalization_3[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 24639361 (93.99 MB)
# Trainable params: 23202561 (88.51 MB)
# Non-trainable params: 1436800 (5.48 MB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

def check_cuda_tensorflow():
    # Check TensorFlow version
    print("TensorFlow version:", tf.__version__)
    
    # Check if TensorFlow can access GPU
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        
        print("TensorFlow is using the following GPU(s):")
        for gpu in gpus:
            print(f" - {gpu}")
        
        # Optional: Print CUDA device properties
        for gpu in gpus:
            details = tf.config.experimental.get_device_details(gpu)
            print(details)
    else:
        print("No GPU available. TensorFlow is using the CPU.")

# Run the check
check_cuda_tensorflow()
# Out:
# TensorFlow version: 2.14.0
# TensorFlow is using the following GPU(s):
#  - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# {'compute_capability': (8, 6), 'device_name': 'NVIDIA GeForce RTX 3060 Laptop GPU'}
# 2024-08-05 01:15:12.704878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Training =412 min 5 seconds

# %%
history = final_model.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=epochs,
    verbose=1,
    validation_data=validation_generator,
    validation_steps=50,
    )
# Out:
# Epoch 1/650
# 100/100 [==============================] - 43s 296ms/step - loss: 7.7263 - binary_accuracy: 0.7194 - precision_3: 0.8859 - recall_3: 0.6107 - auc_3: 0.7836 - val_loss: 7.0701 - val_binary_accuracy: 0.3837 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_3: 0.5000
# Epoch 2/650
# 100/100 [==============================] - 35s 346ms/step - loss: 5.8866 - binary_accuracy: 0.8134 - precision_3: 0.8984 - recall_3: 0.7844 - auc_3: 0.8586 - val_loss: 13.8692 - val_binary_accuracy: 0.3900 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_3: 0.5000
# Epoch 3/650
# 100/100 [==============================] - 39s 389ms/step - loss: 4.5499 - binary_accuracy: 0.8578 - precision_3: 0.9134 - recall_3: 0.8475 - auc_3: 0.8908 - val_loss: 15.8395 - val_binary_accuracy: 0.4075 - val_precision_3: 0.6471 - val_recall_3: 0.0675 - val_auc_3: 0.5083
# Epoch 4/650
# 100/100 [==============================] - 41s 412ms/step - loss: 3.5817 - binary_accuracy: 0.8656 - precision_3: 0.9247 - recall_3: 0.8452 - auc_3: 0.8957 - val_loss: 3.3540 - val_binary_accuracy: 0.8350 - val_precision_3: 0.8227 - val_recall_3: 0.9452 - val_auc_3: 0.8350
# Epoch 5/650
# 100/100 [==============================] - 41s 411ms/step - loss: 2.8489 - binary_accuracy: 0.8709 - precision_3: 0.9256 - recall_3: 0.8598 - auc_3: 0.9005 - val_loss: 2.7265 - val_binary_accuracy: 0.8431 - val_precision_3: 0.7970 - val_recall_3: 0.9959 - val_auc_3: 0.8410
# Epoch 6/650
# 100/100 [==============================] - 43s 426ms/step - loss: 2.2602 - binary_accuracy: 0.8856 - precision_3: 0.9451 - recall_3: 0.8661 - auc_3: 0.9179 - val_loss: 2.6747 - val_binary_accuracy: 0.6856 - val_precision_3: 0.6606 - val_recall_3: 1.0000 - val_auc_3: 0.6337
# Epoch 7/650
# 100/100 [==============================] - 43s 434ms/step - loss: 1.8185 - binary_accuracy: 0.8972 - precision_3: 0.9474 - recall_3: 0.8842 - auc_3: 0.9240 - val_loss: 2.1006 - val_binary_accuracy: 0.7444 - val_precision_3: 0.7011 - val_recall_3: 0.9958 - val_auc_3: 0.7228
# Epoch 8/650
# 100/100 [==============================] - 40s 399ms/step - loss: 1.4658 - binary_accuracy: 0.9053 - precision_3: 0.9455 - recall_3: 0.8981 - auc_3: 0.9304 - val_loss: 2.3155 - val_binary_accuracy: 0.6162 - val_precision_3: 0.6132 - val_recall_3: 0.9990 - val_auc_3: 0.5492
# Epoch 9/650
# 100/100 [==============================] - 39s 389ms/step - loss: 1.1744 - binary_accuracy: 0.9141 - precision_3: 0.9511 - recall_3: 0.9044 - auc_3: 0.9387 - val_loss: 2.6516 - val_binary_accuracy: 0.6363 - val_precision_3: 0.6307 - val_recall_3: 1.0000 - val_auc_3: 0.5432
# Epoch 10/650
# 100/100 [==============================] - 37s 373ms/step - loss: 0.9257 - binary_accuracy: 0.9438 - precision_3: 0.9691 - recall_3: 0.9386 - auc_3: 0.9581 - val_loss: 1.1765 - val_binary_accuracy: 0.8537 - val_precision_3: 0.8137 - val_recall_3: 0.9909 - val_auc_3: 0.8245
# Epoch 11/650
# 100/100 [==============================] - 38s 378ms/step - loss: 0.7763 - binary_accuracy: 0.9353 - precision_3: 0.9646 - recall_3: 0.9273 - auc_3: 0.9515 - val_loss: 1.0655 - val_binary_accuracy: 0.7756 - val_precision_3: 0.7396 - val_recall_3: 0.9980 - val_auc_3: 0.7364
# Epoch 12/650
# 100/100 [==============================] - 37s 370ms/step - loss: 0.6173 - binary_accuracy: 0.9453 - precision_3: 0.9696 - recall_3: 0.9420 - auc_3: 0.9635 - val_loss: 0.7039 - val_binary_accuracy: 0.8650 - val_precision_3: 0.9694 - val_recall_3: 0.8059 - val_auc_3: 0.9045
# Epoch 13/650
# 100/100 [==============================] - 37s 366ms/step - loss: 0.5139 - binary_accuracy: 0.9519 - precision_3: 0.9729 - recall_3: 0.9467 - auc_3: 0.9636 - val_loss: 1.0519 - val_binary_accuracy: 0.7738 - val_precision_3: 0.7335 - val_recall_3: 0.9970 - val_auc_3: 0.7379
# Epoch 14/650
# 100/100 [==============================] - 37s 365ms/step - loss: 0.4349 - binary_accuracy: 0.9513 - precision_3: 0.9679 - recall_3: 0.9521 - auc_3: 0.9610 - val_loss: 0.4701 - val_binary_accuracy: 0.9275 - val_precision_3: 0.9284 - val_recall_3: 0.9550 - val_auc_3: 0.9333
# Epoch 15/650
# 100/100 [==============================] - 37s 372ms/step - loss: 0.3769 - binary_accuracy: 0.9413 - precision_3: 0.9684 - recall_3: 0.9363 - auc_3: 0.9541 - val_loss: 0.4331 - val_binary_accuracy: 0.9244 - val_precision_3: 0.9020 - val_recall_3: 0.9860 - val_auc_3: 0.9295
# Epoch 16/650
# 100/100 [==============================] - 36s 361ms/step - loss: 0.3281 - binary_accuracy: 0.9472 - precision_3: 0.9664 - recall_3: 0.9474 - auc_3: 0.9583 - val_loss: 5.5029 - val_binary_accuracy: 0.6269 - val_precision_3: 0.9950 - val_recall_3: 0.4026 - val_auc_3: 0.7088
# Epoch 17/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.2598 - binary_accuracy: 0.9572 - precision_3: 0.9762 - recall_3: 0.9540 - auc_3: 0.9701 - val_loss: 1.7833 - val_binary_accuracy: 0.6356 - val_precision_3: 0.9072 - val_recall_3: 0.4785 - val_auc_3: 0.7048
# Epoch 18/650
# 100/100 [==============================] - 36s 359ms/step - loss: 0.2266 - binary_accuracy: 0.9594 - precision_3: 0.9738 - recall_3: 0.9601 - auc_3: 0.9704 - val_loss: 0.4993 - val_binary_accuracy: 0.8163 - val_precision_3: 0.9779 - val_recall_3: 0.7311 - val_auc_3: 0.8799
# Epoch 19/650
# 100/100 [==============================] - 36s 362ms/step - loss: 0.1949 - binary_accuracy: 0.9588 - precision_3: 0.9809 - recall_3: 0.9525 - auc_3: 0.9701 - val_loss: 0.4836 - val_binary_accuracy: 0.7569 - val_precision_3: 0.9790 - val_recall_3: 0.6171 - val_auc_3: 0.8325
# Epoch 20/650
# 100/100 [==============================] - 36s 362ms/step - loss: 0.1901 - binary_accuracy: 0.9581 - precision_3: 0.9747 - recall_3: 0.9569 - auc_3: 0.9700 - val_loss: 0.7076 - val_binary_accuracy: 0.7144 - val_precision_3: 0.9923 - val_recall_3: 0.5330 - val_auc_3: 0.7763
# Epoch 21/650
# 100/100 [==============================] - 36s 361ms/step - loss: 0.1766 - binary_accuracy: 0.9544 - precision_3: 0.9695 - recall_3: 0.9557 - auc_3: 0.9689 - val_loss: 0.2630 - val_binary_accuracy: 0.9269 - val_precision_3: 0.9052 - val_recall_3: 0.9801 - val_auc_3: 0.9280
# Epoch 22/650
# 100/100 [==============================] - 36s 364ms/step - loss: 0.1449 - binary_accuracy: 0.9625 - precision_3: 0.9777 - recall_3: 0.9593 - auc_3: 0.9719 - val_loss: 1.6278 - val_binary_accuracy: 0.7237 - val_precision_3: 0.9785 - val_recall_3: 0.5590 - val_auc_3: 0.7794
# Epoch 23/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.1530 - binary_accuracy: 0.9608 - precision_3: 0.9776 - recall_3: 0.9582 - auc_3: 0.9711 - val_loss: 1.0208 - val_binary_accuracy: 0.7613 - val_precision_3: 0.7160 - val_recall_3: 1.0000 - val_auc_3: 0.7239
# Epoch 24/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.1415 - binary_accuracy: 0.9622 - precision_3: 0.9761 - recall_3: 0.9629 - auc_3: 0.9694 - val_loss: 0.8939 - val_binary_accuracy: 0.7300 - val_precision_3: 0.9964 - val_recall_3: 0.5652 - val_auc_3: 0.7916
# Epoch 25/650
# 100/100 [==============================] - 36s 356ms/step - loss: 0.1457 - binary_accuracy: 0.9603 - precision_3: 0.9726 - recall_3: 0.9622 - auc_3: 0.9683 - val_loss: 0.7250 - val_binary_accuracy: 0.6806 - val_precision_3: 0.9979 - val_recall_3: 0.4869 - val_auc_3: 0.7568
# Epoch 26/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.1225 - binary_accuracy: 0.9644 - precision_3: 0.9799 - recall_3: 0.9621 - auc_3: 0.9754 - val_loss: 0.2884 - val_binary_accuracy: 0.8275 - val_precision_3: 0.9745 - val_recall_3: 0.7383 - val_auc_3: 0.8857
# Epoch 27/650
# 100/100 [==============================] - 36s 356ms/step - loss: 0.1312 - binary_accuracy: 0.9622 - precision_3: 0.9769 - recall_3: 0.9615 - auc_3: 0.9705 - val_loss: 0.7799 - val_binary_accuracy: 0.6263 - val_precision_3: 0.9926 - val_recall_3: 0.4044 - val_auc_3: 0.7375
# Epoch 28/650
# 100/100 [==============================] - 36s 357ms/step - loss: 0.1219 - binary_accuracy: 0.9634 - precision_3: 0.9758 - recall_3: 0.9644 - auc_3: 0.9708 - val_loss: 0.4126 - val_binary_accuracy: 0.7525 - val_precision_3: 0.9726 - val_recall_3: 0.6141 - val_auc_3: 0.8154
# Epoch 29/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.1114 - binary_accuracy: 0.9622 - precision_3: 0.9764 - recall_3: 0.9607 - auc_3: 0.9736 - val_loss: 0.9314 - val_binary_accuracy: 0.6150 - val_precision_3: 1.0000 - val_recall_3: 0.3714 - val_auc_3: 0.6918
# Epoch 30/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1047 - binary_accuracy: 0.9688 - precision_3: 0.9803 - recall_3: 0.9695 - auc_3: 0.9758 - val_loss: 0.2796 - val_binary_accuracy: 0.8494 - val_precision_3: 0.9871 - val_recall_3: 0.7685 - val_auc_3: 0.9072
# Epoch 31/650
# 100/100 [==============================] - 35s 353ms/step - loss: 0.1008 - binary_accuracy: 0.9697 - precision_3: 0.9807 - recall_3: 0.9704 - auc_3: 0.9764 - val_loss: 0.5525 - val_binary_accuracy: 0.7212 - val_precision_3: 0.9981 - val_recall_3: 0.5455 - val_auc_3: 0.7884
# Epoch 32/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.1005 - binary_accuracy: 0.9672 - precision_3: 0.9816 - recall_3: 0.9638 - auc_3: 0.9751 - val_loss: 0.1554 - val_binary_accuracy: 0.9425 - val_precision_3: 0.9780 - val_recall_3: 0.9292 - val_auc_3: 0.9573
# Epoch 33/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.1125 - binary_accuracy: 0.9619 - precision_3: 0.9765 - recall_3: 0.9617 - auc_3: 0.9720 - val_loss: 0.2613 - val_binary_accuracy: 0.8594 - val_precision_3: 0.9857 - val_recall_3: 0.7794 - val_auc_3: 0.9065
# Epoch 34/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.1024 - binary_accuracy: 0.9634 - precision_3: 0.9775 - recall_3: 0.9632 - auc_3: 0.9757 - val_loss: 0.1908 - val_binary_accuracy: 0.9050 - val_precision_3: 0.9791 - val_recall_3: 0.8697 - val_auc_3: 0.9457
# Epoch 35/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.1054 - binary_accuracy: 0.9628 - precision_3: 0.9772 - recall_3: 0.9630 - auc_3: 0.9709 - val_loss: 1.2618 - val_binary_accuracy: 0.6775 - val_precision_3: 0.9959 - val_recall_3: 0.4870 - val_auc_3: 0.7494
# Epoch 36/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1007 - binary_accuracy: 0.9666 - precision_3: 0.9794 - recall_3: 0.9660 - auc_3: 0.9741 - val_loss: 0.2424 - val_binary_accuracy: 0.9225 - val_precision_3: 0.8966 - val_recall_3: 0.9900 - val_auc_3: 0.9413
# Epoch 37/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.1098 - binary_accuracy: 0.9638 - precision_3: 0.9743 - recall_3: 0.9664 - auc_3: 0.9726 - val_loss: 0.1172 - val_binary_accuracy: 0.9513 - val_precision_3: 0.9813 - val_recall_3: 0.9402 - val_auc_3: 0.9695
# Epoch 38/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0775 - binary_accuracy: 0.9731 - precision_3: 0.9826 - recall_3: 0.9723 - auc_3: 0.9804 - val_loss: 0.1142 - val_binary_accuracy: 0.9613 - val_precision_3: 0.9773 - val_recall_3: 0.9594 - val_auc_3: 0.9731
# Epoch 39/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0938 - binary_accuracy: 0.9678 - precision_3: 0.9774 - recall_3: 0.9700 - auc_3: 0.9740 - val_loss: 1.3154 - val_binary_accuracy: 0.6888 - val_precision_3: 0.9958 - val_recall_3: 0.4887 - val_auc_3: 0.7454
# Epoch 40/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0997 - binary_accuracy: 0.9684 - precision_3: 0.9766 - recall_3: 0.9721 - auc_3: 0.9744 - val_loss: 0.1456 - val_binary_accuracy: 0.9269 - val_precision_3: 0.9910 - val_recall_3: 0.8898 - val_auc_3: 0.9593
# Epoch 41/650
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0887 - binary_accuracy: 0.9688 - precision_3: 0.9822 - recall_3: 0.9675 - auc_3: 0.9753 - val_loss: 1.8937 - val_binary_accuracy: 0.5987 - val_precision_3: 0.9974 - val_recall_3: 0.3710 - val_auc_3: 0.6909
# Epoch 42/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0834 - binary_accuracy: 0.9725 - precision_3: 0.9797 - recall_3: 0.9758 - auc_3: 0.9791 - val_loss: 1.4521 - val_binary_accuracy: 0.6200 - val_precision_3: 0.9972 - val_recall_3: 0.3664 - val_auc_3: 0.6933
# Epoch 43/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0885 - binary_accuracy: 0.9725 - precision_3: 0.9790 - recall_3: 0.9760 - auc_3: 0.9772 - val_loss: 0.1127 - val_binary_accuracy: 0.9650 - val_precision_3: 0.9607 - val_recall_3: 0.9853 - val_auc_3: 0.9691
# Epoch 44/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0910 - binary_accuracy: 0.9716 - precision_3: 0.9801 - recall_3: 0.9725 - auc_3: 0.9770 - val_loss: 0.1993 - val_binary_accuracy: 0.9375 - val_precision_3: 0.9141 - val_recall_3: 0.9940 - val_auc_3: 0.9407
# Epoch 45/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0727 - binary_accuracy: 0.9762 - precision_3: 0.9848 - recall_3: 0.9769 - auc_3: 0.9827 - val_loss: 0.3301 - val_binary_accuracy: 0.7944 - val_precision_3: 0.9954 - val_recall_3: 0.6680 - val_auc_3: 0.8670
# Epoch 46/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0890 - binary_accuracy: 0.9700 - precision_3: 0.9772 - recall_3: 0.9732 - auc_3: 0.9765 - val_loss: 0.1533 - val_binary_accuracy: 0.9513 - val_precision_3: 0.9374 - val_recall_3: 0.9880 - val_auc_3: 0.9546
# Epoch 47/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0903 - binary_accuracy: 0.9706 - precision_3: 0.9824 - recall_3: 0.9694 - auc_3: 0.9763 - val_loss: 0.1311 - val_binary_accuracy: 0.9525 - val_precision_3: 0.9622 - val_recall_3: 0.9603 - val_auc_3: 0.9649
# Epoch 48/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0744 - binary_accuracy: 0.9756 - precision_3: 0.9813 - recall_3: 0.9783 - auc_3: 0.9812 - val_loss: 0.3276 - val_binary_accuracy: 0.8006 - val_precision_3: 0.9969 - val_recall_3: 0.6718 - val_auc_3: 0.8706
# Epoch 49/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0843 - binary_accuracy: 0.9716 - precision_3: 0.9774 - recall_3: 0.9748 - auc_3: 0.9764 - val_loss: 0.1247 - val_binary_accuracy: 0.9644 - val_precision_3: 0.9732 - val_recall_3: 0.9682 - val_auc_3: 0.9738
# Epoch 50/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0780 - binary_accuracy: 0.9756 - precision_3: 0.9850 - recall_3: 0.9761 - auc_3: 0.9806 - val_loss: 0.4746 - val_binary_accuracy: 0.8144 - val_precision_3: 0.9680 - val_recall_3: 0.7265 - val_auc_3: 0.8612
# Epoch 51/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0783 - binary_accuracy: 0.9706 - precision_3: 0.9825 - recall_3: 0.9695 - auc_3: 0.9798 - val_loss: 0.4051 - val_binary_accuracy: 0.8250 - val_precision_3: 0.9869 - val_recall_3: 0.7144 - val_auc_3: 0.8671
# Epoch 52/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0818 - binary_accuracy: 0.9725 - precision_3: 0.9809 - recall_3: 0.9739 - auc_3: 0.9785 - val_loss: 0.6298 - val_binary_accuracy: 0.7494 - val_precision_3: 0.9813 - val_recall_3: 0.5971 - val_auc_3: 0.8018
# Epoch 53/650
# 100/100 [==============================] - 35s 345ms/step - loss: 0.0910 - binary_accuracy: 0.9694 - precision_3: 0.9796 - recall_3: 0.9707 - auc_3: 0.9756 - val_loss: 1.0072 - val_binary_accuracy: 0.6862 - val_precision_3: 0.9939 - val_recall_3: 0.4929 - val_auc_3: 0.7599
# Epoch 54/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0743 - binary_accuracy: 0.9741 - precision_3: 0.9862 - recall_3: 0.9718 - auc_3: 0.9792 - val_loss: 0.3519 - val_binary_accuracy: 0.8250 - val_precision_3: 0.9957 - val_recall_3: 0.7150 - val_auc_3: 0.8760
# Epoch 55/650
# 100/100 [==============================] - 35s 345ms/step - loss: 0.0855 - binary_accuracy: 0.9747 - precision_3: 0.9826 - recall_3: 0.9762 - auc_3: 0.9802 - val_loss: 0.1445 - val_binary_accuracy: 0.9325 - val_precision_3: 0.9800 - val_recall_3: 0.9076 - val_auc_3: 0.9536
# Epoch 56/650
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0804 - binary_accuracy: 0.9734 - precision_3: 0.9819 - recall_3: 0.9756 - auc_3: 0.9785 - val_loss: 0.2333 - val_binary_accuracy: 0.9200 - val_precision_3: 0.8882 - val_recall_3: 0.9949 - val_auc_3: 0.9368
# Epoch 57/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0696 - binary_accuracy: 0.9772 - precision_3: 0.9862 - recall_3: 0.9767 - auc_3: 0.9816 - val_loss: 0.4325 - val_binary_accuracy: 0.7925 - val_precision_3: 0.9956 - val_recall_3: 0.6730 - val_auc_3: 0.8527
# Epoch 58/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0724 - binary_accuracy: 0.9759 - precision_3: 0.9843 - recall_3: 0.9769 - auc_3: 0.9815 - val_loss: 1.3500 - val_binary_accuracy: 0.6794 - val_precision_3: 1.0000 - val_recall_3: 0.4755 - val_auc_3: 0.7439
# Epoch 59/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0812 - binary_accuracy: 0.9725 - precision_3: 0.9818 - recall_3: 0.9739 - auc_3: 0.9769 - val_loss: 0.6191 - val_binary_accuracy: 0.7119 - val_precision_3: 1.0000 - val_recall_3: 0.5390 - val_auc_3: 0.7871
# Epoch 60/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0750 - binary_accuracy: 0.9753 - precision_3: 0.9842 - recall_3: 0.9757 - auc_3: 0.9819 - val_loss: 1.0589 - val_binary_accuracy: 0.6681 - val_precision_3: 1.0000 - val_recall_3: 0.4554 - val_auc_3: 0.7395
# Epoch 61/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0729 - binary_accuracy: 0.9747 - precision_3: 0.9819 - recall_3: 0.9763 - auc_3: 0.9796 - val_loss: 0.1703 - val_binary_accuracy: 0.9469 - val_precision_3: 0.9257 - val_recall_3: 0.9917 - val_auc_3: 0.9548
# Epoch 62/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0886 - binary_accuracy: 0.9684 - precision_3: 0.9757 - recall_3: 0.9732 - auc_3: 0.9741 - val_loss: 0.1178 - val_binary_accuracy: 0.9600 - val_precision_3: 0.9743 - val_recall_3: 0.9605 - val_auc_3: 0.9729
# Epoch 63/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0738 - binary_accuracy: 0.9722 - precision_3: 0.9778 - recall_3: 0.9773 - auc_3: 0.9763 - val_loss: 0.3634 - val_binary_accuracy: 0.8788 - val_precision_3: 0.8362 - val_recall_3: 0.9990 - val_auc_3: 0.8833
# Epoch 64/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0666 - binary_accuracy: 0.9772 - precision_3: 0.9863 - recall_3: 0.9769 - auc_3: 0.9836 - val_loss: 0.1680 - val_binary_accuracy: 0.9431 - val_precision_3: 0.9172 - val_recall_3: 0.9948 - val_auc_3: 0.9479
# Epoch 65/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0788 - binary_accuracy: 0.9741 - precision_3: 0.9827 - recall_3: 0.9752 - auc_3: 0.9820 - val_loss: 0.2056 - val_binary_accuracy: 0.8994 - val_precision_3: 0.9871 - val_recall_3: 0.8489 - val_auc_3: 0.9432
# Epoch 66/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0800 - binary_accuracy: 0.9722 - precision_3: 0.9811 - recall_3: 0.9736 - auc_3: 0.9798 - val_loss: 1.0681 - val_binary_accuracy: 0.6637 - val_precision_3: 1.0000 - val_recall_3: 0.4689 - val_auc_3: 0.7419
# Epoch 67/650
# 100/100 [==============================] - 34s 342ms/step - loss: 0.0881 - binary_accuracy: 0.9724 - precision_3: 0.9794 - recall_3: 0.9753 - auc_3: 0.9782 - val_loss: 0.7733 - val_binary_accuracy: 0.7169 - val_precision_3: 0.9982 - val_recall_3: 0.5471 - val_auc_3: 0.7815
# Epoch 68/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0644 - binary_accuracy: 0.9797 - precision_3: 0.9855 - recall_3: 0.9809 - auc_3: 0.9856 - val_loss: 0.1360 - val_binary_accuracy: 0.9413 - val_precision_3: 0.9954 - val_recall_3: 0.9066 - val_auc_3: 0.9621
# Epoch 69/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0719 - binary_accuracy: 0.9769 - precision_3: 0.9848 - recall_3: 0.9778 - auc_3: 0.9815 - val_loss: 1.1782 - val_binary_accuracy: 0.6762 - val_precision_3: 0.9978 - val_recall_3: 0.4648 - val_auc_3: 0.7423
# Epoch 70/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0583 - binary_accuracy: 0.9800 - precision_3: 0.9854 - recall_3: 0.9825 - auc_3: 0.9858 - val_loss: 0.1496 - val_binary_accuracy: 0.9525 - val_precision_3: 0.9279 - val_recall_3: 0.9990 - val_auc_3: 0.9585
# Epoch 71/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0735 - binary_accuracy: 0.9753 - precision_3: 0.9859 - recall_3: 0.9746 - auc_3: 0.9815 - val_loss: 1.0055 - val_binary_accuracy: 0.6712 - val_precision_3: 1.0000 - val_recall_3: 0.4708 - val_auc_3: 0.7435
# Epoch 72/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0688 - binary_accuracy: 0.9747 - precision_3: 0.9839 - recall_3: 0.9756 - auc_3: 0.9806 - val_loss: 0.1521 - val_binary_accuracy: 0.9581 - val_precision_3: 0.9412 - val_recall_3: 0.9939 - val_auc_3: 0.9594
# Epoch 73/650
# 100/100 [==============================] - 34s 342ms/step - loss: 0.0629 - binary_accuracy: 0.9750 - precision_3: 0.9826 - recall_3: 0.9766 - auc_3: 0.9814 - val_loss: 0.3268 - val_binary_accuracy: 0.8469 - val_precision_3: 0.9973 - val_recall_3: 0.7503 - val_auc_3: 0.8936
# Epoch 74/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0613 - binary_accuracy: 0.9777 - precision_3: 0.9862 - recall_3: 0.9777 - auc_3: 0.9839 - val_loss: 0.7044 - val_binary_accuracy: 0.7387 - val_precision_3: 0.9946 - val_recall_3: 0.5722 - val_auc_3: 0.7974
# Epoch 75/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0716 - binary_accuracy: 0.9797 - precision_3: 0.9852 - recall_3: 0.9817 - auc_3: 0.9826 - val_loss: 0.1687 - val_binary_accuracy: 0.9244 - val_precision_3: 0.9892 - val_recall_3: 0.8919 - val_auc_3: 0.9491
# Epoch 76/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0557 - binary_accuracy: 0.9828 - precision_3: 0.9879 - recall_3: 0.9844 - auc_3: 0.9853 - val_loss: 0.2510 - val_binary_accuracy: 0.8813 - val_precision_3: 0.9974 - val_recall_3: 0.8056 - val_auc_3: 0.9192
# Epoch 77/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0689 - binary_accuracy: 0.9750 - precision_3: 0.9817 - recall_3: 0.9777 - auc_3: 0.9812 - val_loss: 0.0961 - val_binary_accuracy: 0.9700 - val_precision_3: 0.9676 - val_recall_3: 0.9850 - val_auc_3: 0.9752
# Epoch 78/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0644 - binary_accuracy: 0.9794 - precision_3: 0.9873 - recall_3: 0.9793 - auc_3: 0.9841 - val_loss: 0.1413 - val_binary_accuracy: 0.9644 - val_precision_3: 0.9496 - val_recall_3: 0.9949 - val_auc_3: 0.9640
# Epoch 79/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0576 - binary_accuracy: 0.9819 - precision_3: 0.9887 - recall_3: 0.9816 - auc_3: 0.9865 - val_loss: 0.2191 - val_binary_accuracy: 0.8863 - val_precision_3: 0.9891 - val_recall_3: 0.8247 - val_auc_3: 0.9170
# Epoch 80/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0586 - binary_accuracy: 0.9781 - precision_3: 0.9862 - recall_3: 0.9783 - auc_3: 0.9846 - val_loss: 0.8498 - val_binary_accuracy: 0.7563 - val_precision_3: 0.9965 - val_recall_3: 0.5963 - val_auc_3: 0.8096
# Epoch 81/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0659 - binary_accuracy: 0.9803 - precision_3: 0.9873 - recall_3: 0.9808 - auc_3: 0.9847 - val_loss: 1.2358 - val_binary_accuracy: 0.6669 - val_precision_3: 1.0000 - val_recall_3: 0.4675 - val_auc_3: 0.7473
# Epoch 82/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0620 - binary_accuracy: 0.9797 - precision_3: 0.9865 - recall_3: 0.9811 - auc_3: 0.9819 - val_loss: 0.3333 - val_binary_accuracy: 0.8487 - val_precision_3: 0.9877 - val_recall_3: 0.7558 - val_auc_3: 0.8877
# Epoch 83/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0700 - binary_accuracy: 0.9762 - precision_3: 0.9791 - recall_3: 0.9830 - auc_3: 0.9795 - val_loss: 1.6915 - val_binary_accuracy: 0.6600 - val_precision_3: 1.0000 - val_recall_3: 0.4392 - val_auc_3: 0.7284
# Epoch 84/650
# 100/100 [==============================] - 35s 345ms/step - loss: 0.0509 - binary_accuracy: 0.9847 - precision_3: 0.9891 - recall_3: 0.9855 - auc_3: 0.9877 - val_loss: 0.5956 - val_binary_accuracy: 0.8000 - val_precision_3: 0.9970 - val_recall_3: 0.6798 - val_auc_3: 0.8528
# Epoch 85/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0568 - binary_accuracy: 0.9822 - precision_3: 0.9876 - recall_3: 0.9830 - auc_3: 0.9852 - val_loss: 0.1976 - val_binary_accuracy: 0.9300 - val_precision_3: 0.9045 - val_recall_3: 0.9919 - val_auc_3: 0.9339
# Epoch 86/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0700 - binary_accuracy: 0.9752 - precision_3: 0.9825 - recall_3: 0.9769 - auc_3: 0.9808 - val_loss: 0.5498 - val_binary_accuracy: 0.7781 - val_precision_3: 0.9822 - val_recall_3: 0.6590 - val_auc_3: 0.8323
# Epoch 87/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0618 - binary_accuracy: 0.9818 - precision_3: 0.9880 - recall_3: 0.9818 - auc_3: 0.9857 - val_loss: 0.1348 - val_binary_accuracy: 0.9431 - val_precision_3: 0.9924 - val_recall_3: 0.9156 - val_auc_3: 0.9633
# Epoch 88/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.0571 - binary_accuracy: 0.9828 - precision_3: 0.9873 - recall_3: 0.9848 - auc_3: 0.9852 - val_loss: 0.3775 - val_binary_accuracy: 0.8131 - val_precision_3: 0.9958 - val_recall_3: 0.7069 - val_auc_3: 0.8637
# Epoch 89/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0677 - binary_accuracy: 0.9774 - precision_3: 0.9818 - recall_3: 0.9818 - auc_3: 0.9802 - val_loss: 1.1749 - val_binary_accuracy: 0.6837 - val_precision_3: 0.9939 - val_recall_3: 0.4914 - val_auc_3: 0.7571
# Epoch 90/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0534 - binary_accuracy: 0.9822 - precision_3: 0.9883 - recall_3: 0.9828 - auc_3: 0.9858 - val_loss: 0.3296 - val_binary_accuracy: 0.9025 - val_precision_3: 0.8660 - val_recall_3: 0.9949 - val_auc_3: 0.9072
# Epoch 91/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0581 - binary_accuracy: 0.9797 - precision_3: 0.9877 - recall_3: 0.9791 - auc_3: 0.9850 - val_loss: 1.9367 - val_binary_accuracy: 0.6475 - val_precision_3: 0.9977 - val_recall_3: 0.4307 - val_auc_3: 0.7206
# Epoch 92/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0628 - binary_accuracy: 0.9784 - precision_3: 0.9829 - recall_3: 0.9824 - auc_3: 0.9845 - val_loss: 0.4085 - val_binary_accuracy: 0.8344 - val_precision_3: 0.9971 - val_recall_3: 0.7246 - val_auc_3: 0.8725
# Epoch 93/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0598 - binary_accuracy: 0.9825 - precision_3: 0.9916 - recall_3: 0.9793 - auc_3: 0.9863 - val_loss: 0.1089 - val_binary_accuracy: 0.9644 - val_precision_3: 0.9556 - val_recall_3: 0.9878 - val_auc_3: 0.9635
# Epoch 94/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0666 - binary_accuracy: 0.9778 - precision_3: 0.9856 - recall_3: 0.9781 - auc_3: 0.9840 - val_loss: 0.3081 - val_binary_accuracy: 0.8338 - val_precision_3: 0.9888 - val_recall_3: 0.7326 - val_auc_3: 0.8802
# Epoch 95/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0561 - binary_accuracy: 0.9825 - precision_3: 0.9871 - recall_3: 0.9841 - auc_3: 0.9862 - val_loss: 0.1859 - val_binary_accuracy: 0.9019 - val_precision_3: 0.9976 - val_recall_3: 0.8414 - val_auc_3: 0.9415
# Epoch 96/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0487 - binary_accuracy: 0.9837 - precision_3: 0.9888 - recall_3: 0.9849 - auc_3: 0.9858 - val_loss: 0.0784 - val_binary_accuracy: 0.9706 - val_precision_3: 0.9804 - val_recall_3: 0.9738 - val_auc_3: 0.9723
# Epoch 97/650
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0502 - binary_accuracy: 0.9822 - precision_3: 0.9876 - recall_3: 0.9830 - auc_3: 0.9857 - val_loss: 0.1735 - val_binary_accuracy: 0.9075 - val_precision_3: 0.9953 - val_recall_3: 0.8547 - val_auc_3: 0.9440
# Epoch 98/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0599 - binary_accuracy: 0.9812 - precision_3: 0.9870 - recall_3: 0.9818 - auc_3: 0.9857 - val_loss: 0.3448 - val_binary_accuracy: 0.9169 - val_precision_3: 0.8868 - val_recall_3: 0.9919 - val_auc_3: 0.9075
# Epoch 99/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0578 - binary_accuracy: 0.9784 - precision_3: 0.9883 - recall_3: 0.9769 - auc_3: 0.9858 - val_loss: 0.0833 - val_binary_accuracy: 0.9719 - val_precision_3: 0.9925 - val_recall_3: 0.9604 - val_auc_3: 0.9790
# Epoch 100/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0565 - binary_accuracy: 0.9791 - precision_3: 0.9878 - recall_3: 0.9783 - auc_3: 0.9850 - val_loss: 0.7563 - val_binary_accuracy: 0.7125 - val_precision_3: 0.9981 - val_recall_3: 0.5359 - val_auc_3: 0.7824
# Epoch 101/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0554 - binary_accuracy: 0.9834 - precision_3: 0.9877 - recall_3: 0.9851 - auc_3: 0.9866 - val_loss: 0.6145 - val_binary_accuracy: 0.7475 - val_precision_3: 0.9983 - val_recall_3: 0.5954 - val_auc_3: 0.8117
# Epoch 102/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0515 - binary_accuracy: 0.9819 - precision_3: 0.9882 - recall_3: 0.9822 - auc_3: 0.9867 - val_loss: 0.0963 - val_binary_accuracy: 0.9575 - val_precision_3: 0.9854 - val_recall_3: 0.9461 - val_auc_3: 0.9728
# Epoch 103/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0602 - binary_accuracy: 0.9816 - precision_3: 0.9878 - recall_3: 0.9823 - auc_3: 0.9861 - val_loss: 0.2190 - val_binary_accuracy: 0.8969 - val_precision_3: 0.9514 - val_recall_3: 0.8733 - val_auc_3: 0.9220
# Epoch 104/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0620 - binary_accuracy: 0.9778 - precision_3: 0.9819 - recall_3: 0.9814 - auc_3: 0.9831 - val_loss: 0.2781 - val_binary_accuracy: 0.8850 - val_precision_3: 0.9909 - val_recall_3: 0.8121 - val_auc_3: 0.9165
# Epoch 105/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0570 - binary_accuracy: 0.9784 - precision_3: 0.9846 - recall_3: 0.9801 - auc_3: 0.9836 - val_loss: 0.4416 - val_binary_accuracy: 0.8062 - val_precision_3: 1.0000 - val_recall_3: 0.6774 - val_auc_3: 0.8642
# Epoch 106/650
# 100/100 [==============================] - 35s 350ms/step - loss: 0.0539 - binary_accuracy: 0.9819 - precision_3: 0.9870 - recall_3: 0.9841 - auc_3: 0.9845 - val_loss: 0.0791 - val_binary_accuracy: 0.9725 - val_precision_3: 0.9847 - val_recall_3: 0.9708 - val_auc_3: 0.9850
# Epoch 107/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.0586 - binary_accuracy: 0.9803 - precision_3: 0.9860 - recall_3: 0.9814 - auc_3: 0.9841 - val_loss: 1.6242 - val_binary_accuracy: 0.6388 - val_precision_3: 1.0000 - val_recall_3: 0.4156 - val_auc_3: 0.7154
# Epoch 108/650
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0610 - binary_accuracy: 0.9822 - precision_3: 0.9875 - recall_3: 0.9840 - auc_3: 0.9846 - val_loss: 0.3087 - val_binary_accuracy: 0.8344 - val_precision_3: 0.9943 - val_recall_3: 0.7281 - val_auc_3: 0.8861
# Epoch 109/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0527 - binary_accuracy: 0.9834 - precision_3: 0.9890 - recall_3: 0.9845 - auc_3: 0.9873 - val_loss: 0.6951 - val_binary_accuracy: 0.7200 - val_precision_3: 1.0000 - val_recall_3: 0.5488 - val_auc_3: 0.7941
# Epoch 110/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0507 - binary_accuracy: 0.9856 - precision_3: 0.9891 - recall_3: 0.9871 - auc_3: 0.9892 - val_loss: 0.4346 - val_binary_accuracy: 0.8150 - val_precision_3: 1.0000 - val_recall_3: 0.6992 - val_auc_3: 0.8605
# Epoch 111/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0481 - binary_accuracy: 0.9856 - precision_3: 0.9909 - recall_3: 0.9860 - auc_3: 0.9892 - val_loss: 0.1260 - val_binary_accuracy: 0.9456 - val_precision_3: 0.9912 - val_recall_3: 0.9196 - val_auc_3: 0.9597
# Epoch 112/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0525 - binary_accuracy: 0.9812 - precision_3: 0.9866 - recall_3: 0.9825 - auc_3: 0.9876 - val_loss: 0.1568 - val_binary_accuracy: 0.9212 - val_precision_3: 0.9885 - val_recall_3: 0.8807 - val_auc_3: 0.9504
# Epoch 113/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0637 - binary_accuracy: 0.9781 - precision_3: 0.9821 - recall_3: 0.9821 - auc_3: 0.9817 - val_loss: 0.1074 - val_binary_accuracy: 0.9556 - val_precision_3: 0.9709 - val_recall_3: 0.9560 - val_auc_3: 0.9681
# Epoch 114/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0571 - binary_accuracy: 0.9816 - precision_3: 0.9887 - recall_3: 0.9811 - auc_3: 0.9872 - val_loss: 0.1333 - val_binary_accuracy: 0.9381 - val_precision_3: 0.9807 - val_recall_3: 0.9185 - val_auc_3: 0.9541
# Epoch 115/650
# 100/100 [==============================] - 34s 340ms/step - loss: 0.0502 - binary_accuracy: 0.9828 - precision_3: 0.9876 - recall_3: 0.9841 - auc_3: 0.9861 - val_loss: 0.0840 - val_binary_accuracy: 0.9756 - val_precision_3: 0.9791 - val_recall_3: 0.9820 - val_auc_3: 0.9792
# Epoch 116/650
# 100/100 [==============================] - 35s 345ms/step - loss: 0.0430 - binary_accuracy: 0.9834 - precision_3: 0.9867 - recall_3: 0.9862 - auc_3: 0.9882 - val_loss: 0.1004 - val_binary_accuracy: 0.9669 - val_precision_3: 0.9643 - val_recall_3: 0.9828 - val_auc_3: 0.9687
# Epoch 117/650
# 100/100 [==============================] - 34s 338ms/step - loss: 0.0444 - binary_accuracy: 0.9844 - precision_3: 0.9907 - recall_3: 0.9836 - auc_3: 0.9888 - val_loss: 0.1241 - val_binary_accuracy: 0.9406 - val_precision_3: 0.9936 - val_recall_3: 0.9128 - val_auc_3: 0.9588
# Epoch 118/650
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0567 - binary_accuracy: 0.9772 - precision_3: 0.9873 - recall_3: 0.9759 - auc_3: 0.9822 - val_loss: 0.6395 - val_binary_accuracy: 0.7394 - val_precision_3: 0.9912 - val_recall_3: 0.5783 - val_auc_3: 0.8018
# Epoch 119/650
# 100/100 [==============================] - 34s 341ms/step - loss: 0.0616 - binary_accuracy: 0.9806 - precision_3: 0.9877 - recall_3: 0.9806 - auc_3: 0.9843 - val_loss: 0.1186 - val_binary_accuracy: 0.9538 - val_precision_3: 0.9847 - val_recall_3: 0.9375 - val_auc_3: 0.9704
# Epoch 120/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0502 - binary_accuracy: 0.9834 - precision_3: 0.9889 - recall_3: 0.9845 - auc_3: 0.9857 - val_loss: 0.1808 - val_binary_accuracy: 0.9094 - val_precision_3: 0.9943 - val_recall_3: 0.8612 - val_auc_3: 0.9428
# Epoch 121/650
# 100/100 [==============================] - 34s 342ms/step - loss: 0.0460 - binary_accuracy: 0.9850 - precision_3: 0.9900 - recall_3: 0.9860 - auc_3: 0.9877 - val_loss: 0.3797 - val_binary_accuracy: 0.8369 - val_precision_3: 0.9944 - val_recall_3: 0.7342 - val_auc_3: 0.8785
# Epoch 122/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0582 - binary_accuracy: 0.9791 - precision_3: 0.9861 - recall_3: 0.9796 - auc_3: 0.9854 - val_loss: 0.1877 - val_binary_accuracy: 0.8856 - val_precision_3: 0.9988 - val_recall_3: 0.8185 - val_auc_3: 0.9354
# Epoch 123/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0516 - binary_accuracy: 0.9828 - precision_3: 0.9896 - recall_3: 0.9819 - auc_3: 0.9869 - val_loss: 0.0903 - val_binary_accuracy: 0.9688 - val_precision_3: 0.9706 - val_recall_3: 0.9785 - val_auc_3: 0.9722
# Epoch 124/650
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0467 - binary_accuracy: 0.9853 - precision_3: 0.9915 - recall_3: 0.9850 - auc_3: 0.9884 - val_loss: 0.8006 - val_binary_accuracy: 0.7588 - val_precision_3: 0.9984 - val_recall_3: 0.6127 - val_auc_3: 0.8204
# Epoch 125/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0506 - binary_accuracy: 0.9844 - precision_3: 0.9909 - recall_3: 0.9839 - auc_3: 0.9887 - val_loss: 0.1733 - val_binary_accuracy: 0.9206 - val_precision_3: 0.9897 - val_recall_3: 0.8801 - val_auc_3: 0.9439
# Epoch 126/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0483 - binary_accuracy: 0.9837 - precision_3: 0.9878 - recall_3: 0.9858 - auc_3: 0.9850 - val_loss: 0.3741 - val_binary_accuracy: 0.8281 - val_precision_3: 0.9986 - val_recall_3: 0.7230 - val_auc_3: 0.8774
# Epoch 127/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.0554 - binary_accuracy: 0.9799 - precision_3: 0.9886 - recall_3: 0.9785 - auc_3: 0.9841 - val_loss: 0.2630 - val_binary_accuracy: 0.9131 - val_precision_3: 0.8769 - val_recall_3: 0.9969 - val_auc_3: 0.9084
# Epoch 128/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0572 - binary_accuracy: 0.9800 - precision_3: 0.9856 - recall_3: 0.9816 - auc_3: 0.9847 - val_loss: 0.3195 - val_binary_accuracy: 0.8313 - val_precision_3: 0.9903 - val_recall_3: 0.7305 - val_auc_3: 0.8790
# Epoch 129/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0436 - binary_accuracy: 0.9869 - precision_3: 0.9916 - recall_3: 0.9864 - auc_3: 0.9888 - val_loss: 0.1136 - val_binary_accuracy: 0.9625 - val_precision_3: 0.9438 - val_recall_3: 0.9990 - val_auc_3: 0.9624
# Epoch 130/650
# 100/100 [==============================] - 35s 351ms/step - loss: 0.0577 - binary_accuracy: 0.9819 - precision_3: 0.9877 - recall_3: 0.9826 - auc_3: 0.9848 - val_loss: 0.4679 - val_binary_accuracy: 0.8656 - val_precision_3: 0.8184 - val_recall_3: 1.0000 - val_auc_3: 0.8507
# Epoch 131/650
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0719 - binary_accuracy: 0.9744 - precision_3: 0.9823 - recall_3: 0.9764 - auc_3: 0.9785 - val_loss: 0.0951 - val_binary_accuracy: 0.9606 - val_precision_3: 0.9905 - val_recall_3: 0.9457 - val_auc_3: 0.9731
# Epoch 132/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0443 - binary_accuracy: 0.9875 - precision_3: 0.9912 - recall_3: 0.9881 - auc_3: 0.9908 - val_loss: 0.1639 - val_binary_accuracy: 0.9125 - val_precision_3: 0.9833 - val_recall_3: 0.8762 - val_auc_3: 0.9468
# Epoch 133/650
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0544 - binary_accuracy: 0.9809 - precision_3: 0.9846 - recall_3: 0.9841 - auc_3: 0.9829 - val_loss: 0.1960 - val_binary_accuracy: 0.9212 - val_precision_3: 0.9976 - val_recall_3: 0.8720 - val_auc_3: 0.9466
# Epoch 134/650
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0428 - binary_accuracy: 0.9866 - precision_3: 0.9892 - recall_3: 0.9886 - auc_3: 0.9892 - val_loss: 0.8478 - val_binary_accuracy: 0.7800 - val_precision_3: 0.9892 - val_recall_3: 0.6505 - val_auc_3: 0.8322
# Epoch 135/650
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0470 - binary_accuracy: 0.9837 - precision_3: 0.9890 - recall_3: 0.9850 - auc_3: 0.9873 - val_loss: 1.2731 - val_binary_accuracy: 0.7038 - val_precision_3: 0.9981 - val_recall_3: 0.5284 - val_auc_3: 0.7753
# Epoch 136/650
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0501 - binary_accuracy: 0.9834 - precision_3: 0.9897 - recall_3: 0.9831 - auc_3: 0.9882 - val_loss: 0.1667 - val_binary_accuracy: 0.9350 - val_precision_3: 0.9955 - val_recall_3: 0.8989 - val_auc_3: 0.9581
# Epoch 137/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0617 - binary_accuracy: 0.9809 - precision_3: 0.9860 - recall_3: 0.9825 - auc_3: 0.9848 - val_loss: 0.7406 - val_binary_accuracy: 0.7356 - val_precision_3: 1.0000 - val_recall_3: 0.5770 - val_auc_3: 0.8055
# Epoch 138/650
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0541 - binary_accuracy: 0.9847 - precision_3: 0.9883 - recall_3: 0.9868 - auc_3: 0.9868 - val_loss: 0.3112 - val_binary_accuracy: 0.8869 - val_precision_3: 0.9964 - val_recall_3: 0.8220 - val_auc_3: 0.9169
# Epoch 139/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0575 - binary_accuracy: 0.9812 - precision_3: 0.9841 - recall_3: 0.9860 - auc_3: 0.9850 - val_loss: 1.9165 - val_binary_accuracy: 0.5644 - val_precision_3: 1.0000 - val_recall_3: 0.2844 - val_auc_3: 0.6545
# Epoch 140/650
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0551 - binary_accuracy: 0.9837 - precision_3: 0.9884 - recall_3: 0.9855 - auc_3: 0.9865 - val_loss: 0.1130 - val_binary_accuracy: 0.9569 - val_precision_3: 0.9916 - val_recall_3: 0.9391 - val_auc_3: 0.9707
# Epoch 141/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0532 - binary_accuracy: 0.9803 - precision_3: 0.9864 - recall_3: 0.9819 - auc_3: 0.9832 - val_loss: 0.0938 - val_binary_accuracy: 0.9631 - val_precision_3: 0.9698 - val_recall_3: 0.9688 - val_auc_3: 0.9718
# Epoch 142/650
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0477 - binary_accuracy: 0.9841 - precision_3: 0.9919 - recall_3: 0.9824 - auc_3: 0.9883 - val_loss: 0.1499 - val_binary_accuracy: 0.9344 - val_precision_3: 0.9932 - val_recall_3: 0.8981 - val_auc_3: 0.9582
# Epoch 143/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0623 - binary_accuracy: 0.9821 - precision_3: 0.9873 - recall_3: 0.9838 - auc_3: 0.9858 - val_loss: 0.0988 - val_binary_accuracy: 0.9694 - val_precision_3: 0.9592 - val_recall_3: 0.9918 - val_auc_3: 0.9729
# Epoch 144/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0530 - binary_accuracy: 0.9816 - precision_3: 0.9871 - recall_3: 0.9825 - auc_3: 0.9841 - val_loss: 1.3056 - val_binary_accuracy: 0.6669 - val_precision_3: 0.9978 - val_recall_3: 0.4632 - val_auc_3: 0.7372
# Epoch 145/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0591 - binary_accuracy: 0.9800 - precision_3: 0.9845 - recall_3: 0.9835 - auc_3: 0.9823 - val_loss: 0.0675 - val_binary_accuracy: 0.9762 - val_precision_3: 0.9886 - val_recall_3: 0.9724 - val_auc_3: 0.9830
# Epoch 146/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0459 - binary_accuracy: 0.9881 - precision_3: 0.9929 - recall_3: 0.9879 - auc_3: 0.9900 - val_loss: 0.0952 - val_binary_accuracy: 0.9631 - val_precision_3: 0.9872 - val_recall_3: 0.9518 - val_auc_3: 0.9719
# Epoch 147/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0491 - binary_accuracy: 0.9841 - precision_3: 0.9884 - recall_3: 0.9860 - auc_3: 0.9856 - val_loss: 0.0810 - val_binary_accuracy: 0.9781 - val_precision_3: 0.9716 - val_recall_3: 0.9928 - val_auc_3: 0.9802
# Epoch 148/650
# 100/100 [==============================] - 35s 346ms/step - loss: 0.0438 - binary_accuracy: 0.9844 - precision_3: 0.9895 - recall_3: 0.9856 - auc_3: 0.9892 - val_loss: 0.2285 - val_binary_accuracy: 0.8825 - val_precision_3: 0.9924 - val_recall_3: 0.8124 - val_auc_3: 0.9156
# Epoch 149/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0462 - binary_accuracy: 0.9844 - precision_3: 0.9893 - recall_3: 0.9853 - auc_3: 0.9859 - val_loss: 0.1191 - val_binary_accuracy: 0.9644 - val_precision_3: 0.9541 - val_recall_3: 0.9886 - val_auc_3: 0.9671
# Epoch 150/650
# 100/100 [==============================] - 35s 347ms/step - loss: 0.0504 - binary_accuracy: 0.9831 - precision_3: 0.9839 - recall_3: 0.9889 - auc_3: 0.9859 - val_loss: 0.0724 - val_binary_accuracy: 0.9731 - val_precision_3: 0.9754 - val_recall_3: 0.9804 - val_auc_3: 0.9830
# Epoch 151/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0477 - binary_accuracy: 0.9859 - precision_3: 0.9903 - recall_3: 0.9878 - auc_3: 0.9876 - val_loss: 0.1065 - val_binary_accuracy: 0.9513 - val_precision_3: 0.9881 - val_recall_3: 0.9315 - val_auc_3: 0.9682
# Epoch 152/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0497 - binary_accuracy: 0.9831 - precision_3: 0.9887 - recall_3: 0.9836 - auc_3: 0.9880 - val_loss: 0.2222 - val_binary_accuracy: 0.9050 - val_precision_3: 0.9831 - val_recall_3: 0.8553 - val_auc_3: 0.9288
# Epoch 153/650
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0492 - binary_accuracy: 0.9803 - precision_3: 0.9863 - recall_3: 0.9818 - auc_3: 0.9875 - val_loss: 0.5378 - val_binary_accuracy: 0.7138 - val_precision_3: 0.9853 - val_recall_3: 0.5431 - val_auc_3: 0.7778
# Epoch 154/650
# 100/100 [==============================] - 35s 345ms/step - loss: 0.0480 - binary_accuracy: 0.9841 - precision_3: 0.9873 - recall_3: 0.9868 - auc_3: 0.9877 - val_loss: 0.0819 - val_binary_accuracy: 0.9675 - val_precision_3: 0.9907 - val_recall_3: 0.9570 - val_auc_3: 0.9789
# Epoch 155/650
# 100/100 [==============================] - 34s 342ms/step - loss: 0.0578 - binary_accuracy: 0.9793 - precision_3: 0.9837 - recall_3: 0.9827 - auc_3: 0.9839 - val_loss: 1.6884 - val_binary_accuracy: 0.6644 - val_precision_3: 1.0000 - val_recall_3: 0.4515 - val_auc_3: 0.7339
# Epoch 156/650
# 100/100 [==============================] - 34s 341ms/step - loss: 0.0503 - binary_accuracy: 0.9828 - precision_3: 0.9876 - recall_3: 0.9841 - auc_3: 0.9873 - val_loss: 0.0804 - val_binary_accuracy: 0.9744 - val_precision_3: 0.9662 - val_recall_3: 0.9928 - val_auc_3: 0.9775
# Epoch 157/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0508 - binary_accuracy: 0.9837 - precision_3: 0.9871 - recall_3: 0.9861 - auc_3: 0.9860 - val_loss: 0.0844 - val_binary_accuracy: 0.9762 - val_precision_3: 0.9779 - val_recall_3: 0.9838 - val_auc_3: 0.9813
# Epoch 158/650
# 100/100 [==============================] - 34s 338ms/step - loss: 0.0437 - binary_accuracy: 0.9822 - precision_3: 0.9888 - recall_3: 0.9822 - auc_3: 0.9884 - val_loss: 0.2231 - val_binary_accuracy: 0.9131 - val_precision_3: 0.9977 - val_recall_3: 0.8644 - val_auc_3: 0.9386
# Epoch 159/650
# 100/100 [==============================] - 34s 344ms/step - loss: 0.0449 - binary_accuracy: 0.9831 - precision_3: 0.9860 - recall_3: 0.9870 - auc_3: 0.9851 - val_loss: 0.1259 - val_binary_accuracy: 0.9619 - val_precision_3: 0.9435 - val_recall_3: 0.9980 - val_auc_3: 0.9699
# Epoch 160/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0392 - binary_accuracy: 0.9846 - precision_3: 0.9906 - recall_3: 0.9839 - auc_3: 0.9891 - val_loss: 0.0892 - val_binary_accuracy: 0.9712 - val_precision_3: 0.9662 - val_recall_3: 0.9878 - val_auc_3: 0.9742
# Epoch 161/650
# 100/100 [==============================] - 34s 345ms/step - loss: 0.0530 - binary_accuracy: 0.9803 - precision_3: 0.9847 - recall_3: 0.9832 - auc_3: 0.9830 - val_loss: 0.9343 - val_binary_accuracy: 0.6800 - val_precision_3: 0.9977 - val_recall_3: 0.4632 - val_auc_3: 0.7377
# Epoch 162/650
# 100/100 [==============================] - 34s 342ms/step - loss: 0.0445 - binary_accuracy: 0.9853 - precision_3: 0.9884 - recall_3: 0.9879 - auc_3: 0.9872 - val_loss: 0.3899 - val_binary_accuracy: 0.8050 - val_precision_3: 0.9985 - val_recall_3: 0.6784 - val_auc_3: 0.8595
# Epoch 163/650
# 100/100 [==============================] - 34s 338ms/step - loss: 0.0544 - binary_accuracy: 0.9816 - precision_3: 0.9883 - recall_3: 0.9818 - auc_3: 0.9851 - val_loss: 0.1142 - val_binary_accuracy: 0.9669 - val_precision_3: 0.9543 - val_recall_3: 0.9939 - val_auc_3: 0.9659
# Epoch 164/650
# 100/100 [==============================] - 34s 341ms/step - loss: 0.0444 - binary_accuracy: 0.9859 - precision_3: 0.9907 - recall_3: 0.9860 - auc_3: 0.9886 - val_loss: 0.0780 - val_binary_accuracy: 0.9737 - val_precision_3: 0.9694 - val_recall_3: 0.9902 - val_auc_3: 0.9738
# Epoch 165/650
# 100/100 [==============================] - 34s 343ms/step - loss: 0.0463 - binary_accuracy: 0.9825 - precision_3: 0.9848 - recall_3: 0.9859 - auc_3: 0.9868 - val_loss: 0.0906 - val_binary_accuracy: 0.9688 - val_precision_3: 0.9656 - val_recall_3: 0.9849 - val_auc_3: 0.9751
# Epoch 166/650
# 100/100 [==============================] - 34s 341ms/step - loss: 0.0446 - binary_accuracy: 0.9859 - precision_3: 0.9908 - recall_3: 0.9863 - auc_3: 0.9875 - val_loss: 0.1545 - val_binary_accuracy: 0.9306 - val_precision_3: 0.9913 - val_recall_3: 0.8982 - val_auc_3: 0.9549
# Epoch 167/650
# ...
# Epoch 596/650
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0183 - binary_accuracy: 0.9925 - precision_3: 0.9933 - recall_3: 0.9944 - auc_3: 0.9943 - val_loss: 0.1281 - val_binary_accuracy: 0.9600 - val_precision_3: 0.9968 - val_recall_3: 0.9384 - val_auc_3: 0.9692
# Epoch 597/650
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0257 - binary_accuracy: 0.9916 - precision_3: 0.9945 - recall_3: 0.9921 - auc_3: 0.9929 - val_loss: 0.1338 - val_binary_accuracy: 0.9506 - val_precision_3: 0.9840 - val_recall_3: 0.9350 - val_auc_3: 0.9619
# Epoch 598/650
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0271 - binary_accuracy: 0.9906 - precision_3: 0.9912 - recall_3: 0.9933 - auc_3: 0.9933 - val_loss: 0.7826 - val_binary_accuracy: 0.7319 - val_precision_3: 0.9899 - val_recall_3: 0.5828 - val_auc_3: 0.7954
# Epoch 599/650
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0262 - binary_accuracy: 0.9906 - precision_3: 0.9915 - recall_3: 0.9935 - auc_3: 0.9913 - val_loss: 0.3883 - val_binary_accuracy: 0.8700 - val_precision_3: 0.9963 - val_recall_3: 0.7976 - val_auc_3: 0.9075
# Epoch 600/650
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0269 - binary_accuracy: 0.9916 - precision_3: 0.9927 - recall_3: 0.9932 - auc_3: 0.9929 - val_loss: 0.1455 - val_binary_accuracy: 0.9331 - val_precision_3: 0.9966 - val_recall_3: 0.8949 - val_auc_3: 0.9591
# Epoch 601/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0243 - binary_accuracy: 0.9919 - precision_3: 0.9949 - recall_3: 0.9918 - auc_3: 0.9941 - val_loss: 0.1303 - val_binary_accuracy: 0.9513 - val_precision_3: 0.9870 - val_recall_3: 0.9326 - val_auc_3: 0.9667
# Epoch 602/650
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0263 - binary_accuracy: 0.9919 - precision_3: 0.9938 - recall_3: 0.9928 - auc_3: 0.9931 - val_loss: 0.2280 - val_binary_accuracy: 0.9112 - val_precision_3: 0.9929 - val_recall_3: 0.8607 - val_auc_3: 0.9368
# Epoch 603/650
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0288 - binary_accuracy: 0.9906 - precision_3: 0.9906 - recall_3: 0.9937 - auc_3: 0.9911 - val_loss: 0.1845 - val_binary_accuracy: 0.9156 - val_precision_3: 0.9942 - val_recall_3: 0.8679 - val_auc_3: 0.9434
# Epoch 604/650
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0204 - binary_accuracy: 0.9928 - precision_3: 0.9959 - recall_3: 0.9924 - auc_3: 0.9948 - val_loss: 0.0722 - val_binary_accuracy: 0.9794 - val_precision_3: 0.9790 - val_recall_3: 0.9894 - val_auc_3: 0.9817
# Epoch 605/650
# 100/100 [==============================] - 37s 365ms/step - loss: 0.0339 - binary_accuracy: 0.9875 - precision_3: 0.9904 - recall_3: 0.9894 - auc_3: 0.9885 - val_loss: 0.0697 - val_binary_accuracy: 0.9775 - val_precision_3: 0.9697 - val_recall_3: 0.9938 - val_auc_3: 0.9768
# Epoch 606/650
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0281 - binary_accuracy: 0.9915 - precision_3: 0.9944 - recall_3: 0.9919 - auc_3: 0.9944 - val_loss: 0.6227 - val_binary_accuracy: 0.8044 - val_precision_3: 0.9985 - val_recall_3: 0.6823 - val_auc_3: 0.8525
# Epoch 607/650
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0245 - binary_accuracy: 0.9903 - precision_3: 0.9940 - recall_3: 0.9905 - auc_3: 0.9930 - val_loss: 0.1015 - val_binary_accuracy: 0.9625 - val_precision_3: 0.9906 - val_recall_3: 0.9489 - val_auc_3: 0.9754
# Epoch 608/650
# 100/100 [==============================] - 37s 372ms/step - loss: 0.0280 - binary_accuracy: 0.9887 - precision_3: 0.9904 - recall_3: 0.9914 - auc_3: 0.9917 - val_loss: 1.0273 - val_binary_accuracy: 0.7038 - val_precision_3: 1.0000 - val_recall_3: 0.5118 - val_auc_3: 0.7711
# Epoch 609/650
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0197 - binary_accuracy: 0.9931 - precision_3: 0.9954 - recall_3: 0.9934 - auc_3: 0.9950 - val_loss: 0.1529 - val_binary_accuracy: 0.9575 - val_precision_3: 0.9418 - val_recall_3: 0.9918 - val_auc_3: 0.9566
# Epoch 610/650
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0196 - binary_accuracy: 0.9941 - precision_3: 0.9959 - recall_3: 0.9943 - auc_3: 0.9954 - val_loss: 0.0788 - val_binary_accuracy: 0.9731 - val_precision_3: 0.9855 - val_recall_3: 0.9705 - val_auc_3: 0.9783
# Epoch 611/650
# 100/100 [==============================] - 38s 376ms/step - loss: 0.0312 - binary_accuracy: 0.9900 - precision_3: 0.9935 - recall_3: 0.9906 - auc_3: 0.9910 - val_loss: 0.1359 - val_binary_accuracy: 0.9531 - val_precision_3: 0.9861 - val_recall_3: 0.9371 - val_auc_3: 0.9662
# Epoch 612/650
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0288 - binary_accuracy: 0.9903 - precision_3: 0.9901 - recall_3: 0.9937 - auc_3: 0.9932 - val_loss: 0.2064 - val_binary_accuracy: 0.9100 - val_precision_3: 0.9234 - val_recall_3: 0.9291 - val_auc_3: 0.9346
# Epoch 613/650
# 100/100 [==============================] - 37s 369ms/step - loss: 0.0282 - binary_accuracy: 0.9906 - precision_3: 0.9924 - recall_3: 0.9924 - auc_3: 0.9937 - val_loss: 0.1272 - val_binary_accuracy: 0.9438 - val_precision_3: 0.9816 - val_recall_3: 0.9302 - val_auc_3: 0.9641
# Epoch 614/650
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0297 - binary_accuracy: 0.9884 - precision_3: 0.9919 - recall_3: 0.9895 - auc_3: 0.9920 - val_loss: 0.0868 - val_binary_accuracy: 0.9638 - val_precision_3: 0.9935 - val_recall_3: 0.9463 - val_auc_3: 0.9760
# Epoch 615/650
# 100/100 [==============================] - 37s 369ms/step - loss: 0.0308 - binary_accuracy: 0.9894 - precision_3: 0.9923 - recall_3: 0.9903 - auc_3: 0.9907 - val_loss: 0.0714 - val_binary_accuracy: 0.9744 - val_precision_3: 0.9907 - val_recall_3: 0.9677 - val_auc_3: 0.9821
# Epoch 616/650
# 100/100 [==============================] - 37s 372ms/step - loss: 0.0216 - binary_accuracy: 0.9922 - precision_3: 0.9958 - recall_3: 0.9912 - auc_3: 0.9941 - val_loss: 0.2122 - val_binary_accuracy: 0.9112 - val_precision_3: 0.9988 - val_recall_3: 0.8534 - val_auc_3: 0.9390
# Epoch 617/650
# 100/100 [==============================] - 37s 371ms/step - loss: 0.0299 - binary_accuracy: 0.9891 - precision_3: 0.9906 - recall_3: 0.9911 - auc_3: 0.9921 - val_loss: 0.0851 - val_binary_accuracy: 0.9669 - val_precision_3: 0.9815 - val_recall_3: 0.9647 - val_auc_3: 0.9809
# Epoch 618/650
# 100/100 [==============================] - 37s 372ms/step - loss: 0.0236 - binary_accuracy: 0.9919 - precision_3: 0.9959 - recall_3: 0.9909 - auc_3: 0.9930 - val_loss: 0.3282 - val_binary_accuracy: 0.8931 - val_precision_3: 0.9976 - val_recall_3: 0.8315 - val_auc_3: 0.9252
# Epoch 619/650
# 100/100 [==============================] - 37s 375ms/step - loss: 0.0300 - binary_accuracy: 0.9893 - precision_3: 0.9908 - recall_3: 0.9918 - auc_3: 0.9904 - val_loss: 0.1634 - val_binary_accuracy: 0.9219 - val_precision_3: 0.9967 - val_recall_3: 0.8804 - val_auc_3: 0.9489
# Epoch 620/650
# 100/100 [==============================] - 38s 376ms/step - loss: 0.0263 - binary_accuracy: 0.9909 - precision_3: 0.9923 - recall_3: 0.9928 - auc_3: 0.9926 - val_loss: 0.1563 - val_binary_accuracy: 0.9262 - val_precision_3: 0.9954 - val_recall_3: 0.8840 - val_auc_3: 0.9510
# Epoch 621/650
# 100/100 [==============================] - 38s 381ms/step - loss: 0.0237 - binary_accuracy: 0.9897 - precision_3: 0.9944 - recall_3: 0.9889 - auc_3: 0.9933 - val_loss: 0.2642 - val_binary_accuracy: 0.8888 - val_precision_3: 0.9963 - val_recall_3: 0.8220 - val_auc_3: 0.9187
# Epoch 622/650
# 100/100 [==============================] - 38s 383ms/step - loss: 0.0190 - binary_accuracy: 0.9931 - precision_3: 0.9959 - recall_3: 0.9929 - auc_3: 0.9947 - val_loss: 0.0601 - val_binary_accuracy: 0.9775 - val_precision_3: 0.9865 - val_recall_3: 0.9763 - val_auc_3: 0.9813
# Epoch 623/650
# 100/100 [==============================] - 38s 385ms/step - loss: 0.0230 - binary_accuracy: 0.9925 - precision_3: 0.9949 - recall_3: 0.9929 - auc_3: 0.9934 - val_loss: 0.6319 - val_binary_accuracy: 0.8294 - val_precision_3: 0.9958 - val_recall_3: 0.7264 - val_auc_3: 0.8729
# Epoch 624/650
# 100/100 [==============================] - 38s 383ms/step - loss: 0.0274 - binary_accuracy: 0.9919 - precision_3: 0.9918 - recall_3: 0.9948 - auc_3: 0.9928 - val_loss: 0.0645 - val_binary_accuracy: 0.9812 - val_precision_3: 0.9809 - val_recall_3: 0.9889 - val_auc_3: 0.9826
# Epoch 625/650
# 100/100 [==============================] - 38s 384ms/step - loss: 0.0299 - binary_accuracy: 0.9903 - precision_3: 0.9930 - recall_3: 0.9915 - auc_3: 0.9924 - val_loss: 0.0588 - val_binary_accuracy: 0.9825 - val_precision_3: 0.9827 - val_recall_3: 0.9903 - val_auc_3: 0.9824
# Epoch 626/650
# 100/100 [==============================] - 38s 379ms/step - loss: 0.0238 - binary_accuracy: 0.9909 - precision_3: 0.9934 - recall_3: 0.9919 - auc_3: 0.9930 - val_loss: 0.1083 - val_binary_accuracy: 0.9669 - val_precision_3: 0.9542 - val_recall_3: 0.9939 - val_auc_3: 0.9674
# Epoch 627/650
# 100/100 [==============================] - 38s 382ms/step - loss: 0.0198 - binary_accuracy: 0.9944 - precision_3: 0.9954 - recall_3: 0.9954 - auc_3: 0.9958 - val_loss: 0.1205 - val_binary_accuracy: 0.9663 - val_precision_3: 0.9508 - val_recall_3: 0.9970 - val_auc_3: 0.9624
# Epoch 628/650
# 100/100 [==============================] - 38s 376ms/step - loss: 0.0262 - binary_accuracy: 0.9893 - precision_3: 0.9936 - recall_3: 0.9884 - auc_3: 0.9937 - val_loss: 0.0983 - val_binary_accuracy: 0.9594 - val_precision_3: 0.9641 - val_recall_3: 0.9709 - val_auc_3: 0.9686
# Epoch 629/650
# 100/100 [==============================] - 38s 381ms/step - loss: 0.0253 - binary_accuracy: 0.9928 - precision_3: 0.9929 - recall_3: 0.9954 - auc_3: 0.9938 - val_loss: 0.4628 - val_binary_accuracy: 0.8650 - val_precision_3: 1.0000 - val_recall_3: 0.7857 - val_auc_3: 0.9028
# Epoch 630/650
# 100/100 [==============================] - 38s 384ms/step - loss: 0.0273 - binary_accuracy: 0.9891 - precision_3: 0.9900 - recall_3: 0.9916 - auc_3: 0.9912 - val_loss: 0.1037 - val_binary_accuracy: 0.9569 - val_precision_3: 0.9967 - val_recall_3: 0.9322 - val_auc_3: 0.9729
# Epoch 631/650
# 100/100 [==============================] - 38s 380ms/step - loss: 0.0245 - binary_accuracy: 0.9922 - precision_3: 0.9936 - recall_3: 0.9941 - auc_3: 0.9934 - val_loss: 0.0840 - val_binary_accuracy: 0.9700 - val_precision_3: 0.9896 - val_recall_3: 0.9617 - val_auc_3: 0.9769
# Epoch 632/650
# 100/100 [==============================] - 39s 386ms/step - loss: 0.0163 - binary_accuracy: 0.9947 - precision_3: 0.9960 - recall_3: 0.9955 - auc_3: 0.9970 - val_loss: 0.1251 - val_binary_accuracy: 0.9663 - val_precision_3: 0.9498 - val_recall_3: 0.9980 - val_auc_3: 0.9657
# Epoch 633/650
# 100/100 [==============================] - 38s 378ms/step - loss: 0.0202 - binary_accuracy: 0.9953 - precision_3: 0.9974 - recall_3: 0.9948 - auc_3: 0.9957 - val_loss: 0.0632 - val_binary_accuracy: 0.9800 - val_precision_3: 0.9822 - val_recall_3: 0.9861 - val_auc_3: 0.9816
# Epoch 634/650
# 100/100 [==============================] - 39s 386ms/step - loss: 0.0232 - binary_accuracy: 0.9931 - precision_3: 0.9940 - recall_3: 0.9950 - auc_3: 0.9934 - val_loss: 0.0948 - val_binary_accuracy: 0.9619 - val_precision_3: 0.9989 - val_recall_3: 0.9382 - val_auc_3: 0.9744
# Epoch 635/650
# 100/100 [==============================] - 38s 383ms/step - loss: 0.0235 - binary_accuracy: 0.9912 - precision_3: 0.9944 - recall_3: 0.9914 - auc_3: 0.9928 - val_loss: 0.0903 - val_binary_accuracy: 0.9725 - val_precision_3: 0.9758 - val_recall_3: 0.9778 - val_auc_3: 0.9787
# Epoch 636/650
# 100/100 [==============================] - 39s 388ms/step - loss: 0.0256 - binary_accuracy: 0.9900 - precision_3: 0.9929 - recall_3: 0.9909 - auc_3: 0.9932 - val_loss: 0.0832 - val_binary_accuracy: 0.9712 - val_precision_3: 0.9957 - val_recall_3: 0.9569 - val_auc_3: 0.9790
# Epoch 637/650
# 100/100 [==============================] - 39s 392ms/step - loss: 0.0234 - binary_accuracy: 0.9925 - precision_3: 0.9923 - recall_3: 0.9954 - auc_3: 0.9938 - val_loss: 0.3155 - val_binary_accuracy: 0.8825 - val_precision_3: 0.9962 - val_recall_3: 0.8079 - val_auc_3: 0.9149
# Epoch 638/650
# 100/100 [==============================] - 39s 390ms/step - loss: 0.0268 - binary_accuracy: 0.9928 - precision_3: 0.9945 - recall_3: 0.9940 - auc_3: 0.9943 - val_loss: 0.3099 - val_binary_accuracy: 0.9038 - val_precision_3: 0.9987 - val_recall_3: 0.8393 - val_auc_3: 0.9282
# Epoch 639/650
# 100/100 [==============================] - 39s 389ms/step - loss: 0.0284 - binary_accuracy: 0.9919 - precision_3: 0.9929 - recall_3: 0.9939 - auc_3: 0.9924 - val_loss: 0.3748 - val_binary_accuracy: 0.8706 - val_precision_3: 0.9896 - val_recall_3: 0.7931 - val_auc_3: 0.9030
# Epoch 640/650
# 100/100 [==============================] - 39s 389ms/step - loss: 0.0206 - binary_accuracy: 0.9928 - precision_3: 0.9949 - recall_3: 0.9934 - auc_3: 0.9943 - val_loss: 0.1252 - val_binary_accuracy: 0.9519 - val_precision_3: 0.9459 - val_recall_3: 0.9776 - val_auc_3: 0.9528
# Epoch 641/650
# 100/100 [==============================] - 39s 387ms/step - loss: 0.0217 - binary_accuracy: 0.9925 - precision_3: 0.9934 - recall_3: 0.9944 - auc_3: 0.9935 - val_loss: 0.1303 - val_binary_accuracy: 0.9581 - val_precision_3: 0.9771 - val_recall_3: 0.9543 - val_auc_3: 0.9650
# Epoch 642/650
# 100/100 [==============================] - 39s 390ms/step - loss: 0.0237 - binary_accuracy: 0.9916 - precision_3: 0.9934 - recall_3: 0.9929 - auc_3: 0.9932 - val_loss: 0.1000 - val_binary_accuracy: 0.9681 - val_precision_3: 0.9539 - val_recall_3: 0.9959 - val_auc_3: 0.9687
# Epoch 643/650
# 100/100 [==============================] - 40s 395ms/step - loss: 0.0293 - binary_accuracy: 0.9900 - precision_3: 0.9921 - recall_3: 0.9921 - auc_3: 0.9910 - val_loss: 0.1404 - val_binary_accuracy: 0.9337 - val_precision_3: 0.9943 - val_recall_3: 0.8964 - val_auc_3: 0.9566
# Epoch 644/650
# 100/100 [==============================] - 40s 396ms/step - loss: 0.0295 - binary_accuracy: 0.9909 - precision_3: 0.9925 - recall_3: 0.9930 - auc_3: 0.9929 - val_loss: 0.1020 - val_binary_accuracy: 0.9737 - val_precision_3: 0.9606 - val_recall_3: 0.9980 - val_auc_3: 0.9713
# Epoch 645/650
# 100/100 [==============================] - 40s 396ms/step - loss: 0.0274 - binary_accuracy: 0.9878 - precision_3: 0.9915 - recall_3: 0.9890 - auc_3: 0.9907 - val_loss: 0.1880 - val_binary_accuracy: 0.9200 - val_precision_3: 0.9567 - val_recall_3: 0.9151 - val_auc_3: 0.9546
# Epoch 646/650
# 100/100 [==============================] - 40s 404ms/step - loss: 0.0248 - binary_accuracy: 0.9894 - precision_3: 0.9917 - recall_3: 0.9907 - auc_3: 0.9916 - val_loss: 0.1331 - val_binary_accuracy: 0.9500 - val_precision_3: 0.9978 - val_recall_3: 0.9213 - val_auc_3: 0.9641
# Epoch 647/650
# 100/100 [==============================] - 39s 395ms/step - loss: 0.0178 - binary_accuracy: 0.9944 - precision_3: 0.9969 - recall_3: 0.9939 - auc_3: 0.9957 - val_loss: 0.0852 - val_binary_accuracy: 0.9700 - val_precision_3: 0.9887 - val_recall_3: 0.9630 - val_auc_3: 0.9758
# Epoch 648/650
# 100/100 [==============================] - 40s 400ms/step - loss: 0.0230 - binary_accuracy: 0.9931 - precision_3: 0.9928 - recall_3: 0.9959 - auc_3: 0.9942 - val_loss: 0.1537 - val_binary_accuracy: 0.9413 - val_precision_3: 0.9944 - val_recall_3: 0.9083 - val_auc_3: 0.9586
# Epoch 649/650
# 100/100 [==============================] - 40s 403ms/step - loss: 0.0238 - binary_accuracy: 0.9928 - precision_3: 0.9949 - recall_3: 0.9934 - auc_3: 0.9944 - val_loss: 0.0967 - val_binary_accuracy: 0.9694 - val_precision_3: 0.9801 - val_recall_3: 0.9689 - val_auc_3: 0.9752
# Epoch 650/650
# 100/100 [==============================] - 40s 400ms/step - loss: 0.0270 - binary_accuracy: 0.9906 - precision_3: 0.9939 - recall_3: 0.9909 - auc_3: 0.9932 - val_loss: 0.0494 - val_binary_accuracy: 0.9844 - val_precision_3: 0.9937 - val_recall_3: 0.9803 - val_auc_3: 0.9874

# %%
with open('/home/gourav/Desktop/vss/capstone/history_ResNet50.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
final_model.save('best_driver_ResNet50.h5')

# %% [markdown]
# ## model layers

# %%
visualkeras.layered_view(final_model, 
                         scale_xy=20, 
                         scale_z=0.000001, 
                         max_z=10, 
                         legend=True,
                         font_color=(0, 0, 0))
# Out:
# <PIL.Image.Image image mode=RGBA size=3947x2702>

# %% [markdown]
# ## Testing

# %%
    
model = keras.models.load_model('/home/gourav/Desktop/vss/capstone/best_driver_ResNet50.h5')
compiled_metrics = model.metrics

test_data_generator = ImageDataGenerator(rescale=1.0/255.0)  

test_generator = test_data_generator.flow_from_directory(
    '/home/gourav/Desktop/vss/capstone/dataset/test',
    target_size=(input_shape[0], input_shape[1]),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False 
)

result = model.evaluate(test_generator)

print("Test Loss:", result[0])
print("Test Accuracy:", result[1])
print("Test Accuracy:", result[1]*100)
# Out:
# Found 1269 images belonging to 2 classes.
# 40/40 [==============================] - 4s 79ms/step - loss: 0.5132 - binary_accuracy: 0.8999 - precision: 0.9125 - recall: 0.8852 - auc: 0.9038
# Test Loss: 0.5131614208221436
# Test Accuracy: 0.899921178817749
# Test Accuracy: 89.9921178817749

# %% [markdown]
#  ## Plotting training and validation loss over epochs

# %%
plt.plot(history.history['loss'], label='Loss (training data)')
plt.plot(history.history['val_loss'], label='Loss (validation data)')
plt.title('Loss Over Epochs')
plt.ylabel('Loss Value')
plt.xlabel('Number of Epochs')
plt.legend(loc="upper left")
plt.savefig('Training-Validation_loss_v1_softplus_100_layer_4_original_data.png')
plt.show()

# %% [markdown]
# ## accuracy

# %%
plt.plot(history.history['binary_accuracy'], label='Accuracy (training data)')
plt.plot(history.history['val_binary_accuracy'], label='Accuracy (validation data)')
plt.title('Accuracy over Epochs')
plt.ylabel('Accurcy')
plt.xlabel('Number of epoch')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
# Predictions
y_true = test_generator.classes
y_pred = (model.predict(test_generator) > 0.5).astype('int32').flatten()

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred))

# Confusion Matrix
print("\nConfusion Matrix:")
cm = confusion_matrix(y_true, y_pred)
print(cm)

# Plotting Confusion Matrix
ConfusionMatrixDisplay(confusion_matrix=cm).plot()
plt.title('Confusion Matrix')
plt.show()
# Out:
# 40/40 [==============================] - 4s 78ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       633
#            1       0.91      0.89      0.90       636
#
#     accuracy                           0.90      1269
#    macro avg       0.90      0.90      0.90      1269
# weighted avg       0.90      0.90      0.90      1269
#
#
# Confusion Matrix:
# [[579  54]
#  [ 73 563]]

# %%
# Detailed Accuracy Metrics
print("\nDetailed Accuracy Metrics:")
report = classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys()), output_dict=True)
for label, metrics in report.items():
    if isinstance(metrics, dict):
        print(f"Class '{label}' - Precision: {metrics['precision']:.2f}, Recall: {metrics['recall']:.2f}, F1-Score: {metrics['f1-score']:.2f}")
# Out:
# Detailed Accuracy Metrics:
# Class 'eyes-close' - Precision: 0.89, Recall: 0.91, F1-Score: 0.90
# Class 'eyes-open' - Precision: 0.91, Recall: 0.89, F1-Score: 0.90
# Class 'macro avg' - Precision: 0.90, Recall: 0.90, F1-Score: 0.90
# Class 'weighted avg' - Precision: 0.90, Recall: 0.90, F1-Score: 0.90

# %%
model = keras.models.load_model('/home/gourav/Desktop/vss/capstone/best_driver_ResNet50.h5')
# Save model in the saved_model format
SAVED_MODEL_DIR="/home/gourav/Desktop/vss/tensorrt/models/native_saved_model_resnet"
model.save(SAVED_MODEL_DIR)
# Out:
# 2024-08-22 13:55:25.844179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.849421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.849635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.851497: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.851692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.851848: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.922049: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.922246: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.922432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-22 13:55:25.922680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1197 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:tensorflow:Assets written to: /home/gourav/Desktop/vss/tensorrt/models/native_saved_model_resnet/assets
# INFO:tensorflow:Assets written to: /home/gourav/Desktop/vss/tensorrt/models/native_saved_model_resnet/assets
